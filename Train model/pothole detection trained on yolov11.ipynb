# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vKSFVoXw5W1BLN5NMbwq")
project = rf.workspace("pothole-detection-gbpzy").project("pothole-detection-i00zy-qgqlc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 62.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 82.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Pothole-Detection--1 in yolov11:: 100%|██████████| 7116/7116 [00:01<00:00, 5021.70it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.4 MB/s eta 0:00:00
# ...

# %%
# Install library
# !pip install ultralytics

# Import YOLO
from ultralytics import YOLO

# Load model
model = YOLO("yolo11n.pt")

# Train model
model.train(
    data="/content/Pothole-Detection--1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

# Load your trained or pretrained YOLO11 model
model = YOLO("/content/runs/detect/train/weights/best.pt")   # or "yolo11n.pt" if you're using pretrained

# Run prediction on a video file
results = model.predict(
    source="/content/video 1.mp4",    # path to your video file
    imgsz=640,             # image size for inference
    conf=0.25,         # confidence threshold (default 0.25)
    save=True,             # save output video
    show=True              # show video window while predicting
)
